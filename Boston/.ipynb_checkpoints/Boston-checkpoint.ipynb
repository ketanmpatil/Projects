# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
db=pd.read_csv('housing.csv')

# %%
print(db.head())
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   RM       489 non-null    float64
#  1   LSTAT    489 non-null    float64
#  2   PTRATIO  489 non-null    float64
#  3   MEDV     489 non-null    float64
# dtypes: float64(4)
# memory usage: 15.4 KB

# %%
sns.heatmap(db.isnull())
# Out:
# <AxesSubplot:>

# %%
db.describe()
# Out:
#                RM       LSTAT     PTRATIO          MEDV
# count  489.000000  489.000000  489.000000  4.890000e+02
# mean     6.240288   12.939632   18.516564  4.543429e+05
# std      0.643650    7.081990    2.111268  1.653403e+05
# min      3.561000    1.980000   12.600000  1.050000e+05
# 25%      5.880000    7.370000   17.400000  3.507000e+05
# 50%      6.185000   11.690000   19.100000  4.389000e+05
# 75%      6.575000   17.120000   20.200000  5.187000e+05
# max      8.398000   37.970000   22.000000  1.024800e+06

# %%
corr_matrix = db.corr()
print(corr_matrix)
# Out:
#                RM     LSTAT   PTRATIO      MEDV
# RM       1.000000 -0.612033 -0.304559  0.697209
# LSTAT   -0.612033  1.000000  0.360445 -0.760670
# PTRATIO -0.304559  0.360445  1.000000 -0.519034
# MEDV     0.697209 -0.760670 -0.519034  1.000000

# %%
sns.pairplot(corr_matrix)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X=db.drop(["MEDV"],axis=1)

# %%
y=db["MEDV"]

# %% [markdown]
# ## LINEAR REGRESSION

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,shuffle=True,test_size=0.3)

# %%
print(y_train)
# Out:
# 400    218400.0
# 3      701400.0
# 341    390600.0
# 446    424200.0
# 60     392700.0
#          ...
# 106    409500.0
# 270    953400.0
# 348    474600.0
# 435    338100.0
# 102    390600.0
# Name: MEDV, Length: 342, dtype: float64

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error as mse

from sklearn.metrics import accuracy_score as acs

# %%
mse(y_test,pred)
# Out:
# 7048219280.217689

# %% [markdown]
# ## RIDGE REGRESSION

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,shuffle=True,test_size=0.3)

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
rmodel=Ridge()

# %%
parameters={'alpha':[0.00000001,0.0000001,0.000001,0.00001,0.0001,0.001,0.01,0.1,1,5,10,100,50]}

# %%
rgsv=GridSearchCV(rmodel,parameters)

# %%
rgsv.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [1e-08, 1e-07, 1e-06, 1e-05, 0.0001, 0.001,
#                                    0.01, 0.1, 1, 5, 10, 100, 50]})

# %%
rpred=rgsv.predict(X_test)

# %%
mse(y_test,rpred)
# Out:
# 7014728597.376687

# %% [markdown]
# ## LASSO REGRESSION

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,shuffle=True,test_size=0.3)

# %%
from sklearn.linear_model import Lasso

# %%
lmodel=Lasso()

# %%
lgsv=GridSearchCV(lmodel,parameters)

# %%
lgsv.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=Lasso(),
#              param_grid={'alpha': [1e-08, 1e-07, 1e-06, 1e-05, 0.0001, 0.001,
#                                    0.01, 0.1, 1, 5, 10, 100, 50]})

# %%
lpred=rgsv.predict(X_test)

# %%
mse(y_test,lpred)
# Out:
# 7014728597.376687

# %% [markdown]
# ## SUPPORT VECTOR MACHINE

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,shuffle=True,test_size=0.3)

# %%
from sklearn import svm

# %%
smodel=svm.SVR()

# %%
smodel.fit(X_train,y_train)
# Out:
# SVR()

# %%
spred=smodel.predict(X_test)

# %%
mse(y_test,spred)
# Out:
# 23108941233.40531
